# %% [markdown]
# # 列表（2）

# %% [markdown]
# ## 列表的函数和方法

# %% [markdown]
# ### 假设我们有一个列表 nums = [1, 2, 3]。你可以使用：
#
# **append：**将一个元素添加到列表的末尾
# nums.append(4) 将列表更改为 [1, 2, 3, 4]
# **len：**返回元素的数量
# len(nums) 是 3
# **range：**range(n) 是一个对象，类似于从 0 到 n - 1 的数字列表 这意味着它包含 n 个数字
# 特别地，range(len(nums)) 就像 [0, 1, 2]，这些是 nums 中每个元素的索引
# **[] (下标/索引)：**获取某个索引处的值
# nums[0] 是 1，nums[1] 是 2，nums[2] 是 3
# **+：**连接列表
# nums + [4, 5] 是 [1, 2, 3, 4, 5]

# %% [markdown]
# ### 练习题：
# 现在你将解决四个简短的练习，涉及这些概念。 下面是一组正确和错误的代码行混合在一起。 每个即将到来的练习都有一个解决方案，其中包含下面的正好一行， 你必须从列表中找到正确的行。
#
# x[len(x)] = x[0]
# x[len(x) - 1] = x[0]
# x[len(x) + 1] = x[0]
# x + x[0]
# [x] + x[0]
# x + [x[0]]
# [x] + [x[0]]
# x + x.pop(0)
# [x] + x.pop(0)
# x + [x.pop(0)]
# [x] + [x.pop(0)]
# x.pop(x.append(0))
# x.append(x.pop(0))
# x.append(x[0])
# x.append(x.index(0))
# x.index(x.append(0))
# x.pop(x.index(0))
# x.index(x.pop(0))

# %% [markdown]
# 1. 这是一个不完整的程序：
#
# x = ['a', 'b', 'c']
# (insert_one_line_from_above)
# print(x)
# 用上面列表中的一行替换中间行。最终程序应该修改 x，将第一个元素移动到末尾，以便打印 ['b', 'c', 'a']

# %% [markdown]
# 2. x = ['a', 'b', 'c']
# (insert_one_line_from_above)
# print(x)
# 从列表中选择一行代码，将 x 的最后一个元素覆盖为第一个元素， 这样现在应该打印 ['a', 'b', 'a']

# %% [markdown]
# 通过 x[len(x) - 1] 访问最后一个元素有点麻烦。 同样的效果可以通过 x[-1] 来实现。 类似地，倒数第二个元素 x[len(x) - 2] 可以写成 x[-2]，依此类推  Python 也允许我们从最后一个元素开始向后计数，使用 -1

# %% [markdown]
# 3. 你将创建一个新列表 y，而不是修改列表 x：
#
# x = ['a', 'b', 'c']
# y = (insert_one_line_from_above)
# print(y)
# y 应该与 x 相同，但在末尾也有第一个元素的重复。 因此程序将打印 ['a', 'b', 'c', 'a']

# %% [markdown]
# 4. x = [1, 2, 0, 3]
# x.remove(0)
# print(x)
# 用列表中的一行替换中间行 x.remove(0)，使其完成同样的功能

# %% [markdown]
# ## 更多列表函数和方法

# %% [markdown]
# ### 这里有一些更有用的函数/方法
# **sorted：**接受一个可迭代对象，并返回一个从小到大的元素列表
# **in：**一个比较运算符，用于检查一个值是否在列表中
# **sum：**使用以下语法将一个可迭代的数字相加
# **count：****使用以下语法返回参数在列表中出现的次数

# %% [markdown]
# ### 练习题：
# 现在你将解决另一组涉及这些新概念的四个练习。 同样，正确和错误的代码行混合在一起， 你必须从列表中选择正确的行。
#
# sum(len(x))
# sum(range(x))
# sum(range(len(x)))
# sum(len(range(x)))
# sum(range(x)) + 1
# sum(range(x + 1))
# sum(x) / len(x)
# sum(x) / range(x)
# sum(x) / range(len(x))
# sum(x) / len(range(x))
# sorted(x)[1]
# sorted(x)[2]
# sorted(x)[-1]
# sorted(x)[-2]
# x.count(1) >= 0
# x.count(1) > 0
# x.count(1) > 1

# %% [markdown]
# 1.
